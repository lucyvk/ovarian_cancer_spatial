# %% [markdown]
# This file performs K-Means clustering on the 216 features used for prediction, with the number of groups set to 4 to match theory of ovarian cancer subtypes.

# %%
import os
import pandas as pd
from sklearn.cluster import KMeans
import sklearn
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 1.0.2.

# %%
DATA_FILE = os.path.join('Data','mibi_table_main.csv')
df_orig = pd.read_csv(DATA_FILE)

# Remove ID and outcomes to cluster just on features
df = df_orig.drop(labels=['fov_id','TMA_ID','PFS','OS','OS_high','PFS_high','Primary','Recurrence','Death'],axis=1)
assert len(df.columns) == 216, f"unexpected feature length, {len(df.columns)}"
#print(df.columns.values.tolist())

# Replace NA values with the mean of that column
mean = df.mean()
df.fillna(mean, inplace=True)

# Normalize all the columns before clustering
df=(df-df.mean())/df.std()
print(df)

X = df.to_numpy()
print(X)
# Out:
#     CD8+ T cells_assort  CD8+ T cells_prop  CD8+ T cells_region  \
# 0             -0.106953           0.236041             0.094694
# 1              1.347605           2.648545             2.014089
# 2             -0.581531          -0.416611            -0.340943
# 3              0.153444          -0.025814             0.086600
# 4             -0.146928           0.084471            -0.023723
# ..                  ...                ...                  ...
# 72            -1.148825          -0.613270            -1.908599
# 73            -1.148825          -0.613270            -1.908599
# 74            -1.148825          -0.613270            -1.908599
# 75            -1.148825          -0.613270            -1.908599
# 76            -1.148825          -0.613270            -1.908599
#
#     CD8+ T cells_tumor_med_dist  CD8+ T cells_tumor_contact  \
# 0                 -8.707584e-01                    1.895720
# 1                 -9.761482e-01                   -0.221999
# 2                 -4.013274e-01                    0.413879
# 3                 -8.168863e-01                    0.422966
# 4                 -7.618399e-01                   -0.342685
# ..                          ...                         ...
# 72                -3.313602e-16                    0.008544
# 73                -3.313602e-16                    0.008544
# 74                -3.313602e-16                    0.008544
# 75                -3.313602e-16                    0.008544
# 76                -3.313602e-16                    0.008544
#
#     CD8+ T cells_M1_med_dist  CD8+ T cells_M1_contact  \
# 0              -6.346496e-01                -1.246072
# 1              -1.049108e+00                -0.520739
# 2               2.331465e-01                -0.866124
# 3              -9.063145e-01                 1.215252
# 4              -8.599285e-01                 0.541801
# ..                       ...                      ...
# 72              3.505386e-16                -0.523655
# 73              3.505386e-16                -0.523655
# 74              3.505386e-16                -0.523655
# 75              3.505386e-16                -0.523655
# 76              3.505386e-16                -0.523655
#
#     CD8+ T cells_vascular_med_dist  CD8+ T cells_vascular_contact  \
# 0                    -7.443418e-01                       0.314545
# 1                    -9.183172e-01                       1.141037
# 2                    -2.647376e-01                       1.272118
# 3                    -7.865039e-01                       2.928902
# 4                    -6.953243e-01                      -0.643795
# ..                             ...                            ...
# 72                    3.203536e-16                      -0.550816
# 73                    3.203536e-16                      -0.550816
# 74                    3.203536e-16                      -0.550816
# 75                    3.203536e-16                      -0.550816
# 76                    3.203536e-16                      -0.550816
#
#     CD4+ T cells_assort  ...  HLADR+_M1_med_dist  HLADR+_M1_contact  \
# 0              0.852356  ...        2.241660e-01           0.467974
# 1              1.695231  ...       -4.802400e-01          -0.076050
# 2              0.500035  ...       -6.563969e-01           0.381261
# 3              0.326202  ...       -6.436186e-16          -0.197992
# 4             -0.180008  ...        8.102838e-01          -0.467099
# ..                  ...  ...                 ...                ...
# 72            -0.928668  ...       -6.436186e-16          -0.197992
# 73            -0.928668  ...       -6.436186e-16          -0.197992
# 74            -0.928668  ...        2.329893e+00          -0.290897
# 75            -0.928668  ...       -6.436186e-16          -0.197992
# 76            -0.928668  ...       -6.436186e-16          -0.197992
#
#     HLADR+_vascular_med_dist  HLADR+_vascular_contact  BRCA_Mutation  \
# 0              -1.935766e-01                 0.058789   1.742592e+00
# 1              -6.997565e-01                -1.167501   1.742592e+00
# 2              -4.630311e-01                 0.732206  -8.228905e-01
# 3              -1.255743e-15                -0.111963   2.848258e-16
# 4              -1.445924e-01                -0.319047  -8.228905e-01
# ..                       ...                      ...            ...
# 72             -1.255743e-15                -0.111963  -8.228905e-01
# 73             -1.255743e-15                -0.111963   2.848258e-16
# 74             -6.160583e-01                -0.351783   2.848258e-16
# 75             -1.255743e-15                -0.111963   1.742592e+00
# 76             -1.255743e-15                -0.111963   2.848258e-16
#
#          Age  H3K14Ace      ATF6     DUSP1      CBX2
# 0  -1.591817  1.716898 -0.733814  0.248450  0.258454
# 1  -0.619811 -1.047682  0.345874  0.825252  0.258454
# 2   1.032598 -1.156097  0.885719  0.120271 -0.890683
# 3   0.740996  0.253297  0.165926  0.729119  1.929926
# 4  -0.036608  0.361712  1.065667  0.056182 -0.420581
# ..       ...       ...       ...       ...       ...
# 72  1.324200 -1.156097  0.165926 -0.296308 -0.681749
# 73  1.421400  1.066408 -1.813503 -0.841067  1.407591
# 74  0.157793  0.415919 -0.193970 -0.168130  1.982159
# 75  1.421400  0.144882 -0.733814  0.088227  1.355357
# 76 -0.814212 -0.830852 -0.373918 -0.969245 -0.159414
#
# [77 rows x 216 columns]
# [[-0.10695304  0.23604148  0.09469429 ... -0.7338143   0.24844967
#    0.25845402]
#  [ 1.34760498  2.64854507  2.01408931 ...  0.34587426  0.82525241
#    0.25845402]
#  [-0.58153117 -0.41661107 -0.34094258 ...  0.88571853  0.12027128
#   -0.89068275]
#  ...
#  [-1.14882512 -0.61327001 -1.90859935 ... -0.19397002 -0.16813009
#    1.98215917]
#  [-1.14882512 -0.61327001 -1.90859935 ... -0.7338143   0.08822668
#    1.3553573 ]
#  [-1.14882512 -0.61327001 -1.90859935 ... -0.37391811 -0.96924501
#   -0.1594139 ]]

# %%
SEED = 1989
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=SEED, copy_x=True, algorithm='auto', verbose=1)
out = kmeans.fit(X)
print(out.labels_)
# Out:
# Initialization complete
# Iteration 0, inertia 24080.833979872834
# Iteration 1, inertia 15135.432502747692
# Iteration 2, inertia 14880.069583120568
# Iteration 3, inertia 14724.933829744494
# Iteration 4, inertia 14668.9135295015
# Converged at iteration 4: strict convergence.
# Initialization complete
# Iteration 0, inertia 22646.266481458177
# Iteration 1, inertia 14994.419077228318
# Iteration 2, inertia 14896.25470489588
# Iteration 3, inertia 14859.994540147121
# Iteration 4, inertia 14735.94392705613
# Iteration 5, inertia 14592.780260546017
# Iteration 6, inertia 14445.244261288699
# Iteration 7, inertia 14394.697430204096
# Converged at iteration 7: strict convergence.
# Initialization complete
# Iteration 0, inertia 23552.122599746126
# Iteration 1, inertia 14738.943602772377
# Iteration 2, inertia 14535.374631302187
# Iteration 3, inertia 14428.31605124131
# Iteration 4, inertia 14398.159182417372
# Converged at iteration 4: strict convergence.
# Initialization complete
# Iteration 0, inertia 23644.61518936932
# Iteration 1, inertia 14783.574633903903
# Iteration 2, inertia 14587.293089586334
# Iteration 3, inertia 14513.497828809777
# Iteration 4, inertia 14494.730038275397
# Converged at iteration 4: strict convergence.
# Initialization complete
# Iteration 0, inertia 23099.902136359746
# Iteration 1, inertia 14891.894372459139
# Iteration 2, inertia 14766.019706547153
# Iteration 3, inertia 14721.271981369888
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 23090.24993699666
# Iteration 1, inertia 14621.574956472168
# Iteration 2, inertia 14439.07223879957
# Iteration 3, inertia 14343.157051210314
# Iteration 4, inertia 14327.301140590485
# Converged at iteration 4: strict convergence.
# Initialization complete
# Iteration 0, inertia 23859.919344838476
# Iteration 1, inertia 14703.381214656172
# Iteration 2, inertia 14659.485990515379
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 22324.658323134343
# Iteration 1, inertia 15028.058806923129
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 26311.576278160283
# Iteration 1, inertia 14944.739608592696
# Iteration 2, inertia 14709.525114064247
# Iteration 3, inertia 14562.95432099937
# Iteration 4, inertia 14534.987955198087
# Iteration 5, inertia 14491.7692141675
# Iteration 6, inertia 14475.556467690762
# Iteration 7, inertia 14452.842564659617
# Converged at iteration 7: strict convergence.
# Initialization complete
# Iteration 0, inertia 24762.433450656255
# Iteration 1, inertia 14821.779095942333
# Iteration 2, inertia 14538.789062879265
# Iteration 3, inertia 14439.740723209874
# Iteration 4, inertia 14420.231669459696
# Iteration 5, inertia 14408.168453469023
# Iteration 6, inertia 14385.382024440487
# Converged at iteration 6: strict convergence.
# [1 1 1 1 0 0 3 0 1 1 1 1 2 1 1 0 0 1 2 2 0 1 3 1 0 1 0 0 2 1 1 0 0 2 0 0 0
#  1 2 0 1 3 3 2 3 3 1 3 0 1 2 0 0 1 0 0 0 1 0 1 1 1 1 1 3 0 0 0 0 0 0 2 0 2
#  2 2 0]

# %%
if not os.path.exists("Clustering_Results"):
    os.mkdir("Clustering_Results")
cluster_df = df_orig[['fov_id','TMA_ID','PFS','OS','OS_high','PFS_high','Primary','Recurrence','Death']].copy()
cluster_df['cluster_labels'] = out.labels_.copy()
print(cluster_df)
cluster_df.to_csv(os.path.join('Clustering_Results/cluster_labels.csv'), index=False)
# Out:
#     fov_id  TMA_ID  PFS   OS  OS_high  PFS_high  Primary  Recurrence  Death  \
# 0        9      92  122  122        1         1        1           0      0
# 1        6      87   12   75        1         0        0           1      1
# 2       10      93   30  112        1         1        0           1      1
# 3       15      98   38  153        1         1        0           1      0
# 4       18     102   13   78        1         0        1           1      1
# ..     ...     ...  ...  ...      ...       ...      ...         ...    ...
# 72      56      13   15   29        0         0        1           1      1
# 73      37     126   35   35        0         1        1           0      1
# 74      69      46   15   15        0         0        1           0      1
# 75      76      61   26   82        1         1        1           1      1
# 76      44     139   10   38        0         0        1           1      1
#
#     cluster_labels
# 0                1
# 1                1
# 2                1
# 3                1
# 4                0
# ..             ...
# 72               0
# 73               2
# 74               2
# 75               2
# 76               0
#
# [77 rows x 10 columns]
